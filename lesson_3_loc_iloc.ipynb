# %% [markdown]
# https://www.youtube.com/watch?v=mBCG9J1TVTc&list=PLUaB-1hjhk8GZOuylZqLz-Qt9RIdZZMBE&index=3

# %%
import pandas as pd

# %%
df = pd.read_excel("data/world_population_excel_workbook.xlsx")

# %%
# df = df.set_index(['Country'])
df.set_index(['Country'], inplace=True)
df.reset_index(inplace=True)

# Alternatively:
df = pd.read_excel("data/world_population_excel_workbook.xlsx", index_col='Country')

# %%
df.sort_values(by=["Country"], inplace=True)

# %%
df.loc['Albania']
# Out:
# Rank                               138
# CCA3                               ALB
# Capital                         Tirana
# Continent                       Europe
# 2022 Population                2842321
# 2020 Population                2866849
# 2015 Population                2882481
# 2010 Population                2913399
# 2000 Population                3182021
# 1990 Population                3295066
# 1980 Population                2941651
# 1970 Population                2324731
# Area (kmÂ²)                      28748
# Density (per kmÂ²)             98.8702
# Growth Rate                     0.9957
# World Population Percentage       0.04
# Name: Albania, dtype: object

# %%
df.iloc[1]  # Even when it's indexed by labels and not integers as by default
# Out:
# Rank                               138
# CCA3                               ALB
# Capital                         Tirana
# Continent                       Europe
# 2022 Population                2842321
# 2020 Population                2866849
# 2015 Population                2882481
# 2010 Population                2913399
# 2000 Population                3182021
# 1990 Population                3295066
# 1980 Population                2941651
# 1970 Population                2324731
# Area (kmÂ²)                      28748
# Density (per kmÂ²)             98.8702
# Growth Rate                     0.9957
# World Population Percentage       0.04
# Name: Albania, dtype: object

# %%
df.reset_index(inplace=True)
df.set_index(['Continent', 'Country'], inplace=True)

# %%
df.sort_index(ascending=[True, False], inplace=True)
df
# Out:
#                               Rank CCA3       Capital  2022 Population  \
# Continent     Country
# Africa        Zimbabwe          74  ZWE        Harare         16320537
#               Zambia            63  ZMB        Lusaka         20017675
#               Western Sahara   172  ESH     El AaiÃºn           575986
#               Uganda            31  UGA       Kampala         47249585
#               Tunisia           79  TUN         Tunis         12356117
# ...                            ...  ...           ...              ...
# South America Colombia          28  COL        Bogota         51874024
#               Chile             65  CHL      Santiago         19603733
#               Brazil             7  BRA      Brasilia        215313498
#               Bolivia           80  BOL         Sucre         12224110
#               Argentina         33  ARG  Buenos Aires         45510318
#
#                               2020 Population  2015 Population  \
# Continent     Country
# ...

# %%
df.loc['Africa']
# Out:
#                           Rank CCA3       Capital  2022 Population  \
# Country
# Zimbabwe                    74  ZWE        Harare         16320537
# Zambia                      63  ZMB        Lusaka         20017675
# Western Sahara             172  ESH     El AaiÃºn           575986
# Uganda                      31  UGA       Kampala         47249585
# Tunisia                     79  TUN         Tunis         12356117
# Togo                       100  TGO         LomÃ©          8848699
# Tanzania                    22  TZA        Dodoma         65497748
# Sudan                       32  SDN      Khartoum         46874204
# South Sudan                 86  SSD          Juba         10913164
# South Africa                24  ZAF      Pretoria         59893885
# Somalia                     70  SOM     Mogadishu         17597511
# Sierra Leone               102  SLE      Freetown          8605718
# Seychelles                 196  SYC      Victoria           107118
# ...

# %%
df.loc['Africa', 'Zambia']
# Out:
# Rank                                 63
# CCA3                                ZMB
# Capital                          Lusaka
# 2022 Population                20017675
# 2020 Population                18927715
# 2015 Population                16248230
# 2010 Population                13792086
# 2000 Population                 9891136
# 1990 Population                 7686401
# 1980 Population                 5720438
# 1970 Population                 4281671
# Area (kmÂ²)                      752612
# Density (per kmÂ²)              26.5976
# Growth Rate                       1.028
# World Population Percentage        0.25
# Name: (Africa, Zambia), dtype: object

# %%
df.iloc[1]  # iloc is using values from before we have set the multi-indexes
# Out:
# Rank                                 63
# CCA3                                ZMB
# Capital                          Lusaka
# 2022 Population                20017675
# 2020 Population                18927715
# 2015 Population                16248230
# 2010 Population                13792086
# 2000 Population                 9891136
# 1990 Population                 7686401
# 1980 Population                 5720438
# 1970 Population                 4281671
# Area (kmÂ²)                      752612
# Density (per kmÂ²)              26.5976
# Growth Rate                       1.028
# World Population Percentage        0.25
# Name: (Africa, Zambia), dtype: object

# %%
df.xs('Australia', level='Country')
# Out:
#            Rank CCA3   Capital  2022 Population  2020 Population  \
# Continent
# Oceania      55  AUS  Canberra         26177413         25670051
#
#            2015 Population  2010 Population  2000 Population  1990 Population  \
# Continent
# Oceania           23820236         22019168         19017963         17048003
#
#            1980 Population  1970 Population  Area (kmÂ²)  Density (per kmÂ²)  \
# Continent
# Oceania           14706322         12595034      7692024              3.4032
#
#            Growth Rate  World Population Percentage
# Continent
# Oceania         1.0099                         0.33
